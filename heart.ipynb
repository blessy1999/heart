# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/heart.csv')
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data['age'].value_counts().head()
# Out:
# 58    68
# 57    57
# 54    53
# 59    46
# 52    43
# Name: age, dtype: int64

# %%
data[data['age'] >= 50].value_counts().head()
# Out:
# age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# 64   1    2   125       309   0    1        131      1      1.8      1      0   3     0         4
# 55   0    0   128       205   0    2        130      1      2.0      1      1   3     0         4
# 63   0    0   108       269   0    1        169      1      1.8      1      2   2     0         4
#               150       407   0    0        154      0      4.0      1      3   3     0         4
# 57   1    2   128       229   0    0        150      0      0.4      1      1   3     0         4
# dtype: int64

# %%
data['chol'].value_counts().head()
# Out:
# 204    21
# 234    21
# 197    19
# 212    18
# 254    17
# Name: chol, dtype: int64

# %%
plt.figure(figsize = (8,8))
plt.bar(list(data['chol'].value_counts()[0:5].keys()),list(data['chol'].value_counts()[0:5].keys()))
plt.show()

# %%
age_chol = data[['age','chol']]
age_chol.head()
# Out:
#    age  chol
# 0   52   212
# 1   53   203
# 2   70   174
# 3   61   203
# 4   62   294

# %%
age_chol = age_chol.sort_values(by=['age'],ascending=False)
age_chol.head()
# Out:
#      age  chol
# 387   77   304
# 162   77   304
# 160   77   304
# 965   76   197
# 99    76   197

# %%
plt.figure(figsize=(8,5))
plt.bar(list(age_chol['chol'])[0:5], list(age_chol['age'])[0:5])
plt.show()

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.sort_values(by = ['thalach'],ascending=False).head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 64    29    1   1       130   204    0        0      202      0      0.0
# 668   29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 60    29    1   1       130   204    0        0      202      0      0.0
# 326   54    1   1       192   283    0        0      195      0      0.0
#
#      slope  ca  thal  target
# 64       2   0     2       1
# 668      2   0     2       1
# 118      2   0     2       1
# 60       2   0     2       1
# 326      2   1     3       0

# %%
data.sort_values(by = ['slope'],ascending=False).head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 558   39    0   2        94   199    0        1      179      0      0.0
# 543   59    1   3       134   204    0        1      162      0      0.8
# 547   67    0   0       106   223    0        1      142      0      0.3
# 548   51    0   2       120   295    0        0      157      0      0.6
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 558      2   0     2       1
# 543      2   2     2       0
# 547      2   2     2       1
# 548      2   0     2       1
